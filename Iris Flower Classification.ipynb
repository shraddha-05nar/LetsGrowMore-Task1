# %% [markdown]
# ##***LetsGrowMore***
# **Data Science Internship**
#
# **Name: Shraddha Narvekar**

# %% [markdown]
# #Iris Flower Classification-TASK 1
# The aim is to clasify Iris flowers among three species from measurements of sepals and petal's length and width which are given in cm.
#
# The Iris dataset contains 3 classes of 50 instances each, where each class refers to type of iris plant.
#
# Three classes available are:-
#
# *   Iris Setosa
# *   Iris Versicolor
#
# *   Iris Verginica

# %% [markdown]
# ##Import Modules

# %%
import pandas as pd                #To store the data sets
import numpy as np                  #To carry out operations with the arrays.
import os                            # used to handle some files if necessary
import matplotlib.pyplot as plt       # Visualize the data in the form of graphs
import seaborn as sns                  # visualize graphs

# %% [markdown]
# ##Loading the Dataset

# %%
df = pd.read_csv('Iris.csv')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#To delete Id column
df1=df.drop(columns=['Id'])

# %%
df1.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# To display basic statiscs
df1.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
# for info about datatype
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# to display number of samples of each class
df1['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# ##Pre-processing the data

# %%
#the null values should be removed or replaced with mean median or mode
df1.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
# No null values for the corresponding database

# %% [markdown]
# ##Exploratory Data Analysis
# To visualize the data in the form of graphs

# %% [markdown]
# ###Histogram

# %%
df1['SepalLengthCm'].hist()
# Out:
# <Axes: >

# %%
df1['SepalWidthCm'].hist()
# Out:
# <Axes: >

# %%
df1['PetalLengthCm'].hist()
# Out:
# <Axes: >

# %%
df1['PetalWidthCm'].hist()
# Out:
# <Axes: >

# %% [markdown]
# ###Scatterplot

# %%
colors = ['blue','green','purple']
species = ['Iris-setosa','Iris-versicolor','Iris-virginica']

# %%
for i in range(3):
  x = df1[df1['Species'] == species[i]] # filter classes from the dataset
  plt.scatter(x['SepalLengthCm'], x['SepalWidthCm'], c = colors[i], label=species[i])

plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.legend()

# %%
for i in range(3):
  x = df1[df1['Species'] == species[i]] # filter classes from the dataset
  plt.scatter(x['PetalLengthCm'], x['PetalWidthCm'], c = colors[i], label=species[i])

plt.xlabel("Petal Length")
plt.ylabel("Petal Width")
plt.legend()

# %%
for i in range(3):
  x = df1[df1['Species'] == species[i]] # filter classes from the dataset
  plt.scatter(x['SepalLengthCm'], x['PetalLengthCm'], c = colors[i], label=species[i])

plt.xlabel("Sepal Length")
plt.ylabel("Petal Length")
plt.legend()

# %%
for i in range(3):
  x = df1[df1['Species'] == species[i]] # filter classes from the dataset
  plt.scatter(x['SepalWidthCm'], x['PetalWidthCm'], c = colors[i], label=species[i])

plt.xlabel("Sepal Width")
plt.ylabel("Petal Width")
plt.legend()

# %% [markdown]
# ##Correlation Matrix

# %% [markdown]
# A correlation matrix is a table showing correlation coefficients between variables.
#
# The value is in the range of -1 to 1. If two variable have high correlation, we can neglect one variable from those two.

# %%
# creating correlation matrix - correlation matrix is used to understand the importance between two variables
df1.corr()
# Out:
# <ipython-input-45-e2db0033c610>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.corr()
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %% [markdown]
# Heatmap

# %%
corr = df1.corr()
fig, ax = plt.subplots(figsize=(5,4)) # to set the size of the graphs
sns.heatmap(corr, annot=True, ax=ax)
# Out:
# <ipython-input-51-4626cbfa4086>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df1.corr()
# <Axes: >

# %% [markdown]
# ##Label Encoder
# Label encoding is a technique used in machine learning and data analysis to convert categorical variables into numerical format

# %%
# import label encoder module
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df1['Species'] = le.fit_transform(df1['Species'])
df1.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            5.1           3.5            1.4           0.2        0
# 1            4.9           3.0            1.4           0.2        0
# 2            4.7           3.2            1.3           0.2        0
# 3            4.6           3.1            1.5           0.2        0
# 4            5.0           3.6            1.4           0.2        0

# %% [markdown]
# ##Model Training

# %%
from sklearn.model_selection import train_test_split
# train - 70%
# test - 30%
X = df1.drop(columns=['Species'])
Y = df1['Species']
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.30)

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(x_train, y_train) # training the model
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# print metric to get performance
print("Accuracy: ",model.score(x_test, y_test) * 100)
# Out:
# Accuracy:  95.55555555555556

# %% [markdown]
# knn - k-nearest neighbours

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
# print metric to get performance
print("Accuracy: ",model.score(x_test, y_test) * 100)
# Out:
# Accuracy:  93.33333333333333

# %% [markdown]
# Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()

# %%
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# print metric to get performance
print("Accuracy: ",model.score(x_test, y_test) * 100)
# Out:
# Accuracy:  93.33333333333333
